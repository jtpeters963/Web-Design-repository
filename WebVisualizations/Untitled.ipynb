# %%
import pandas as pd

# %%
df=pd.read_csv("Resources/cities.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       Name Country  Lattitude  Longitude  Max Temperature (k)  \
# 0           0    Mataura      NZ     -46.19     168.86               294.26
# 1           1      Vaini      TO     -21.20    -175.20               300.15
# 2           2   Bengkulu      ID      -3.80     102.27               302.61
# 3           3  Ilulissat      GL      69.22     -51.10               272.15
# 4           4  Busselton      AU     -33.65     115.33               304.82
#
#    % Humidity  Wind Speed  Cloud Coverage              Time
# 0          47        4.02               0  22:48 04-10-2020
# 1          65        3.60              20  22:48 04-10-2020
# 2          63        0.93             100  22:48 04-10-2020
# 3          46        4.60              61  22:48 04-10-2020
# 4          28        3.24              51  22:48 04-10-2020

# %%
del df['Unnamed: 0']

# %%
df.set_index(df['Name'], inplace=True)
del df['Name']
df.head()
# Out:
#           Country  Lattitude  Longitude  Max Temperature (k)  % Humidity  \
# Name
# Mataura        NZ     -46.19     168.86               294.26          47
# Vaini          TO     -21.20    -175.20               300.15          65
# Bengkulu       ID      -3.80     102.27               302.61          63
# Ilulissat      GL      69.22     -51.10               272.15          46
# Busselton      AU     -33.65     115.33               304.82          28
#
#            Wind Speed  Cloud Coverage              Time
# Name
# Mataura          4.02               0  22:48 04-10-2020
# Vaini            3.60              20  22:48 04-10-2020
# Bengkulu         0.93             100  22:48 04-10-2020
# Ilulissat        4.60              61  22:48 04-10-2020
# Busselton        3.24              51  22:48 04-10-2020

# %%
df.to_html('data.html')
